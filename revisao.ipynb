# %%
#Ex.1
usuario = str(input("Digite o usuario: "))

if usuario == 'admin':
    senha = int(input("Digite a senha: "))

    if senha == 1234:
        print("Acesso permitido")
    else:
        print("Senha incorreta")
else:
    print("Acesso negado")
# Out:
# Senha incorreta

# %%
#Ex.2
idade = int(input("Digite a sua idade: "))

if idade >= 18:
    if idade >= 60:
        print("Idoso")
    else:
        if idade >=18 and idade <60:
            print("Adulto")
else:
    if idade >=12:
        print("Adolescente")
    else:
        print("Criança")
# Out:
# Idoso

# %%
#Ex.3
nota = float(input("Digite a nota: "))

if nota >=6:
    if  nota >= 9:
        print("Aprovado com excelência")
    else:
         print("Aprovado")
else:
    print("Reprovado")
# Out:
# Reprovado

# %%
#Ex.4
numero = int(input("Digite um numero"))

if numero >0:
    if numero %2 == 0:
        print("Positivo e par")
    else:
        print("Positivo e ímpar")
else:
    if numero == 0:
        print("Zero")
    else:
        print("Negativo")
# Out:
# Positivo e par

# %%
#Ex.5
valor = float(input("Digite o valor da compra: "))
vip = input("A pessoa e VIP? (sim/nao): ")

if valor >= 200:
    if vip == "sim":
        desconto = valor * 0.20
        valor_final = valor - desconto
        print("Desconto de 20% aplicado!")
    else:
        desconto = valor * 0.10
        valor_final = valor - desconto
        print(f"Desconto de 10% aplicado!")
    
    print(f"Valor do desconto: R$ {desconto:.2f}")
    print(f"Valor final: R$ {valor_final:.2f}")
else:
    print("Nao ha desconto disponivel.")
# Out:
# Desconto de 20% aplicado!
# Valor do desconto: R$ 60.00
# Valor final: R$ 240.00

# %%
#Ex.6
dia = input("Digite o dia da semana: ")

if dia == "sabado":
    print("Dia de festa!")
elif dia == "domingo":
    condicao = input("Voce esta com dor de cabeca? (sim/nao): ")
    
    if condicao == "sim":
        print("Recuperando, entao precisa descansar.")
    else:
        print("Apenas descanse.")
else:
    print("Trabalhando!")

# %%
#Ex.7
print("Menu de cafe da manha:")
print("1. Eggs")
print("2. Pancakes")
print("3. Wafles")
print("4. Frutas")

opcao = input("Escolha uma opcao (1 a 4): ")

if opcao == "1":
    acompanhamento = input("Qual acompanhamento deseja? ")
    print(f"Voce escolheu Eggs com {acompanhamento}. Bom apetite!")

elif opcao == "2":
    print("Voce escolheu Pancakes. Deliciosa escolha!")

elif opcao == "3":
    print("Voce escolheu Wafles. Otima escolha!")

elif opcao == "4":
    fruta = input("Qual tipo de fruta deseja? ")
    acompanhamento = input("Deseja algum acompanhamento? ")
    print(f"Voce escolheu {fruta} com {acompanhamento}. Opcao saudavel!")

else:
    print("Opcao invalida. Tente novamente.")

# %%
#Ex.8
numero = True

if numero == True:
    print("Faça alguma coisa")
else:
    print("Faça outra coisa")
# Out:
# True

# %%
#Ex.9
numero = False

if numero == False:
    print("Faça alguma coisa")
else:
    print("Faça outra coisa")

# %%
#Ex.10
temperatura = int(input("Digite uma temperatura"))
esta_frio = temperatura < 18
if esta_frio == True:
    print("Está frio")
else:
    print("Não está frio")

# %%
#Ex.11
senha = str(input("Digite sua senha"))
senha_correta = senha == '1234'

if senha_correta == True:
    print("Senha correta")
else:
    print("Senha incorreta")
# Out:
# Senha correta

# %%
#Ex.12
numero = int(input("Digite um número"))
numero_par = numero %2 == 0

if numero_par == True:
    print("Par!")
else:
    print("Ímpar!")
# Out:
# Par!

# %%
#Ex.13
salario = int(input("Digite o salario"))

salario1 = salario <= 2000
salario2 = 2000 <= salario == 3500
salario3 = 3500 <= salario == 5000
salario4 = salario > 5000

if salario1 == True:
    print(salario)
    if salariosalario2 == True:
        desconto = valor * 0.10
        valor_final = valor - desconto
        if salario3 == True

# %%
#Ex.13
salario = int(input("Digite o salario"))
salario1 = (salario <= 2000)
salario2 = (salario <= 3500)
salario3 = (salario <=5000)
salario4 = (salario>5000)

if salario1 == True:
    desconto = 0

elif salario2 == True:
    desconto = salario * 0.10

elif salario3 == True:
    desconto = salario * 0.20

else:
    desconto = salario * 0.275

salario_final = salario - desconto
print(f"O desconto aplicado será de: R$ {desconto}")
print(f"salario final será: R$ {salario_final}")
# Out:
# O desconto aplicado será de: R$ 13750.000000000002
# salario final será: R$ 36250.0
